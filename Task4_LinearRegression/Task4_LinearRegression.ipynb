# %% [markdown]
# # Implementation Task 4 - Linear Regression
# ---
#
# ## Linear Regression
# ---
#
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ### Load Dataset

# %%
canada = pd.read_csv("canada_per_capita_income.csv")
print("Dataset Shape: ", canada.shape)

# print(canada.head())

X = canada[['year']]   
y = canada['per capita income (US$)']
# Out:
# Dataset Shape:  (47, 2)

# %% [markdown]
# ### Train Regression Model

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predict income for 2020

# %%
year = pd.DataFrame([[2020]], columns=['year'])
predictedIncome = model.predict(year)
print("Predicted Income:", predictedIncome)
# Out:
# Predicted Income: [41288.69409442]

# %% [markdown]
# ### Model Evaluation

# %%
y_pred = model.predict(X)
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

print("Model Evaluation Metrics:")
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R² Score:", r2)
# Out:
# Model Evaluation Metrics:
# Mean Absolute Error: 3088.866427771443
# Mean Squared Error: 15462739.061504772
# Root Mean Squared Error: 3932.268945723928
# R² Score: 0.890916917957032

# %% [markdown]
# ### Visualization

# %%
plt.scatter(X, y, color='blue', label="Actual Data")
plt.plot(X, y_pred, color='red', label="Regression Line")
plt.xlabel("Year")
plt.ylabel("Per Capita Income")
plt.title("Per Capita Income Prediction")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ## Multiple Linear Regression
#
# ---
#
# ### Libraries Imported Already
# --
# ### Load Dataset

# %%
hiring = pd.read_csv("hiring.csv")
print("Dataset Shape: ", hiring.shape)

def convert_to_int(word):
    word_dict = {
        'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10, 'eleven': 11, 'twelve': 12, 'zero': 0, np.nan: 0
    }
    return word_dict.get(word, 0)

hiring['experience'] = hiring['experience'].apply(convert_to_int)
hiring['test_score(out of 10)'] = hiring['test_score(out of 10)'].fillna(hiring['test_score(out of 10)'].mean())

a = hiring[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']]
b = hiring['salary($)']
# Out:
# Dataset Shape:  (8, 4)

# %% [markdown]
# ### Train Model

# %%
model = LinearRegression()
model.fit(a, b)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions

# %%
candidates = pd.DataFrame([[2, 9, 6], [12, 10, 10]], columns=['experience', 'test_score(out of 10)', 'interview_score(out of 10)'])

predictedSalaries = model.predict(candidates)

print("Predicted Salaries:", predictedSalaries[0], predictedSalaries[1])
# Out:
# Predicted Salaries: 53290.892559447646 92268.07227783566

# %% [markdown]
# ### Model Evaluation

# %%
b_pred = model.predict(a)
mae_1 = mean_absolute_error(b, b_pred)
mse_1 = mean_squared_error(b, b_pred)
rmse_1 = np.sqrt(mse)
r2_1= r2_score(b, b_pred)

print("Model Evaluation Metrics:")
print("Mean Absolute Error:",mae_1)
print("Mean Squared Error", mse_1)
print("Root Mean Squared Error:",rmse_1)
print("R² Score:", r2_1)
# Out:
# Model Evaluation Metrics:
# Mean Absolute Error: 1739.7560385573815
# Mean Squared Error 4167481.961463801
# Root Mean Squared Error: 3932.268945723928
# R² Score: 0.9639958361860579
